# %% [markdown]
# <a href="https://colab.research.google.com/github/zezinjr/Iniciandojornada/blob/main/Extra%C3%A7%C3%A3o%20e%20tratamento%20de%20dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-36ae8e54-96e7-48da-a5d5-b88dd3dc7ec6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-36ae8e54-96e7-48da-a5d5-b88dd3dc7ec6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('Data - data.csv')
df.head()

# %%
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611121   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
df.isna().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
df.dropna(subset=['Description', 'CustomerID'])
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899          CHILDREN'S APRON DOLLY GIRL         6
# 541906    581587     23254         CHILDRENS CUTLERY DOLLY GIRL         4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138         BAKING SET 9 PIECE RETROSPOT         3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df = df.dropna(subset=['Description', 'CustomerID'])
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#        InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 08:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 08:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 08:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 08:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 08:26       3.39     17850.0  United Kingdom

# %%
df[(df.UnitPrice < 0) & (df.UnitPrice == 0)].head()
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country]
# Index: []

# %%
df = df[df.UnitPrice > 0]
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#        InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 08:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 08:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 08:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 08:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 08:26       3.39     17850.0  United Kingdom

# %%
df[(df.Quantity < 0) & (df.Quantity == 0)].head()
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country]
# Index: []

# %%
df = df[df.Quantity > 0]
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#        InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 08:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 08:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 08:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 08:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 08:26       3.39     17850.0  United Kingdom

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, 0 to 4
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   InvoiceNo    5 non-null      object
#  1   StockCode    5 non-null      object
#  2   Description  5 non-null      object
#  3   Quantity     5 non-null      int64
#  4   InvoiceDate  5 non-null      object
#  5   UnitPrice    5 non-null      float64
#  6   CustomerID   5 non-null      float64
#  7   Country      5 non-null      object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 532.0+ bytes

# %%
pd.to_datetime(df.InvoiceDate)
# Out:
# 0        2010-12-01 08:26:00
# 1        2010-12-01 08:26:00
# 2        2010-12-01 08:26:00
# 3        2010-12-01 08:26:00
# 4        2010-12-01 08:26:00
#                  ...
# 541904   2011-12-09 12:50:00
# 541905   2011-12-09 12:50:00
# 541906   2011-12-09 12:50:00
# 541907   2011-12-09 12:50:00
# 541908   2011-12-09 12:50:00
# Name: InvoiceDate, Length: 541909, dtype: datetime64[ns]

# %%
df['InvoiceDate'] = pd.to_datetime(df.InvoiceDate)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %%
df['CustomerID'].fillna(0, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2c58359d3311> in <cell line: 1>()
# ----> 1 df['CustomerID'].fillna(0, inplace=True)
#
# NameError: name 'df' is not defined

# %%
df['CustomerID'] = df['CustomerID'].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   541909 non-null  int64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(2), object(4)
# memory usage: 33.1+ MB

# %%
import seaborn as sns
sns.boxplot(df)
# Out:
# <Axes: >

# %%
def is_outlier(array, extreme=True):
  Q1 = df['Quantity'].quantile(0.25)
  Q3 = df['UnitPrice'].quantile(0.75)
  IQR = Q3 - Q1
  lower = Q1 - 1.5*IQR
  upper = Q3 + 1.5*IQR

  factor = 3. if extreme else 1.5

  upper_array = np.where(df['Quantity'] >= upper)[10000]
  lower_array = np.where(df['UnitPrice'] <= lower)[5000]

  df.drop(index=upper_array, inplace=True)
  df.drop(index=lower_array, inplace=True)

# %%
df[['Quantity', 'UnitPrice']]
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#        InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice
# 0  12/1/2010 08:26       2.55     17850.0  United Kingdom       15.30
# 1  12/1/2010 08:26       3.39     17850.0  United Kingdom       20.34
# 2  12/1/2010 08:26       2.75     17850.0  United Kingdom       22.00
# 3  12/1/2010 08:26       3.39     17850.0  United Kingdom       20.34
# 4  12/1/2010 08:26       3.39     17850.0  United Kingdom       20.34

# %%
df['TotalPrice'] = df['Quantity'] * df['UnitPrice']
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-9029186c77b0> in <cell line: 1>()
# ----> 1 df['TotalPrice'] = df['Quantity'] * df['UnitPrice']
#       2 df.head()
#
# NameError: name 'df' is not defined

# %%
max(df.InvoiceDate)
# Out:
# '9/9/2011 17:52'

# %%
>>> import matplotlib.pyplot as plt
>>> df.plot(x="Rank", y=["P25th", "Median", "P75th"])
>>> plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-3491acaaa73f> in <cell line: 2>()
#       1 import matplotlib.pyplot as plt
# ----> 2 df.plot(x="Rank", y=["P25th", "Median", "P75th"])
#       3 plt.show()
#
# NameError: name 'df' is not defined
